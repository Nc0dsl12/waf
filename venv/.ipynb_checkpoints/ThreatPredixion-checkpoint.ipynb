# %%
import pandas as pd
import numpy as np

# %%
dat_df= pd.read_json('complete_clean.json')

# %%
dat_df
# Out:
#                                                  pattern   type
# 0      crteyreti=wsn&et3tf6shov=tdsviee y fum$oh3;ore...  valid
# 1                                                *;q=0.7  valid
# 2                                     nhgiopie/7.8.4.7.0  valid
# 3      /dyylkl.xd9cpu/4ot0ta/ts6xnrp1/hssh/a2cuerht/s...  valid
# 4      /2m6vlb1r37jspc/cwvv/mbar/oqrd0/msc/etceebwgi/...  valid
# ...                                                  ...    ...
# 90248             <img onpointerenter=alert(1)>xss</img>    xss
# 90249  <source onbeforepaste="alert(1)" contenteditab...    xss
# 90250  <div draggable="true" contenteditable>drag me<...    xss
# 90251  <li><cite id="citerefdomingos2015" class="cita...  valid
# 90252                                            </span>  valid
#
# [90253 rows x 2 columns]

# %%
counts = dat_df['type'].value_counts()

# %%
import matplotlib
matplotlib.use('TkAgg')  # or 'Qt5Agg' if you prefer
import matplotlib.pyplot as plt

# %%
X = dat_df['pattern'].to_numpy().astype(str)
y = dat_df['type'].to_numpy().astype(str)

# %%
print(len(X))
print(len(y))
# Out:
# 90253
# 90253

# %%
counts.plot.pie(figsize=(5, 5))
# Out:
# <Axes: ylabel='count'>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV, train_test_split

# %%
trainX, testX, trainY, testY = train_test_split(X, y, test_size = 0.25, random_state = 42, stratify = y)

np.savez('dataset', trainX=trainX, testX=testX, trainY=trainY, testY=testY)

# %%
pipe = make_pipeline(TfidfVectorizer(input = 'content', lowercase = True, analyzer = 'char', max_features = 1024), SVC())

param_grid = {'tfidfvectorizer__ngram_range': [(1, 1), (1, 2), (1, 4)], 'svc__C': [1, 10], 'svc__kernel': ['linear', 'rbf']}

grid = GridSearchCV(pipe, param_grid, cv = 2, verbose = 4)

grid.fit(trainX, trainY)
# Out:
# Fitting 2 folds for each of 12 candidates, totalling 24 fits
# [CV 1/2] END svc__C=1, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 1);, score=0.959 total time=  42.8s
# [CV 2/2] END svc__C=1, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 1);, score=0.960 total time=  42.9s
# [CV 1/2] END svc__C=1, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 2);, score=0.985 total time= 2.4min
# [CV 2/2] END svc__C=1, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 2);, score=0.986 total time= 2.3min
# [CV 1/2] END svc__C=1, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 4);, score=0.986 total time= 2.1min
# [CV 2/2] END svc__C=1, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 4);, score=0.987 total time= 2.1min
# [CV 1/2] END svc__C=1, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 1);, score=0.982 total time=  36.1s
# [CV 2/2] END svc__C=1, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 1);, score=0.983 total time=  36.3s
# [CV 1/2] END svc__C=1, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 2);, score=0.989 total time= 3.4min
# [CV 2/2] END svc__C=1, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 2);, score=0.990 total time= 3.4min
# [CV 1/2] END svc__C=1, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 4);, score=0.989 total time= 3.1min
# [CV 2/2] END svc__C=1, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 4);, score=0.991 total time= 3.2min
# [CV 1/2] END svc__C=10, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 1);, score=0.966 total time=  30.5s
# [CV 2/2] END svc__C=10, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 1);, score=0.968 total time=  31.0s
# [CV 1/2] END svc__C=10, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 2);, score=0.990 total time= 1.7min
# [CV 2/2] END svc__C=10, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 2);, score=0.990 total time= 1.7min
# [CV 1/2] END svc__C=10, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 4);, score=0.990 total time= 1.6min
# [CV 2/2] END svc__C=10, svc__kernel=linear, tfidfvectorizer__ngram_range=(1, 4);, score=0.990 total time= 1.6min
# [CV 1/2] END svc__C=10, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 1);, score=0.987 total time=  26.9s
# [CV 2/2] END svc__C=10, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 1);, score=0.988 total time=  27.4s
# [CV 1/2] END svc__C=10, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 2);, score=0.993 total time= 3.4min
# [CV 2/2] END svc__C=10, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 2);, score=0.994 total time= 3.5min
# [CV 1/2] END svc__C=10, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 4);, score=0.993 total time= 3.0min
# [CV 2/2] END svc__C=10, svc__kernel=rbf, tfidfvectorizer__ngram_range=(1, 4);, score=0.994 total time= 3.1min
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('tfidfvectorizer',
#                                         TfidfVectorizer(analyzer='char',
#                                                         max_features=1024)),
#                                        ('svc', SVC())]),
#              param_grid={'svc__C': [1, 10], 'svc__kernel': ['linear', 'rbf'],
#                          'tfidfvectorizer__ngram_range': [(1, 1), (1, 2),
#                                                           (1, 4)]},
#              verbose=4)

# %%
grid.score(testX, testY)
# Out:
# 0.995789753589789

# %%
from sklearn.metrics import classification_report

preds = grid.predict(testX)

print(classification_report(testY, preds))
# Out:
#                 precision    recall  f1-score   support
#
#           cmdi       0.99      0.98      0.98       865
# path-traversal       1.00      0.97      0.98       822
#           sqli       1.00      0.99      0.99      3288
#          valid       1.00      1.00      1.00     15156
#            xss       1.00      1.00      1.00      2433
#
#       accuracy                           1.00     22564
#      macro avg       0.99      0.99      0.99     22564
#   weighted avg       1.00      1.00      1.00     22564

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

# Create confusion matrix
cm = confusion_matrix(testY, grid.predict(testX))

# Plot it
ConfusionMatrixDisplay(confusion_matrix=cm).plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 8
#       6 # Plot it
#       7 ConfusionMatrixDisplay(confusion_matrix=cm).plot()
# ----> 8 plt.show()
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:612, in show(*args, **kwargs)
#     568 """
#     569 Display all open figures.
#     570
#    (...)
#     609 explicitly there.
#     610 """
#     611 _warn_if_gui_out_of_main_thread()
# --> 612 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backend_bases.py:3553, in _Backend.show(cls, block)
#    3551     block = not ipython_pylab and not is_interactive()
#    3552 if block:
# -> 3553     cls.mainloop()
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\_backend_tk.py:520, in FigureManagerTk.start_main_loop(cls)
#     518 manager_class._owns_mainloop = True
#     519 try:
# --> 520     first_manager.window.mainloop()
#     521 finally:
#     522     manager_class._owns_mainloop = False
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\tkinter\__init__.py:1599, in Misc.mainloop(self, n)
#    1597 def mainloop(self, n=0):
#    1598     """Call the mainloop of Tk."""
# -> 1599     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
grid.best_params_
# Out:
# {'svc__C': 10, 'svc__kernel': 'rbf', 'tfidfvectorizer__ngram_range': (1, 2)}

# %%
pipe = make_pipeline(TfidfVectorizer(input = 'content', lowercase = True, analyzer = 'char', max_features = 1024, ngram_range = (1, 2)), SVC(C = 10, kernel = 'rbf'))

pipe.fit(trainX, trainY)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 3
#       1 pipe = make_pipeline(TfidfVectorizer(input = 'content', lowercase = True, analyzer = 'char', max_features = 1024, ngram_range = (1, 2)), SVC(C = 10, kernel = 'rbf'))
# ----> 3 pipe.fit(trainX, trainY)
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\pipeline.py:660, in Pipeline.fit(self, X, y, **params)
#     654     if self._final_estimator != "passthrough":
#     655         last_step_params = self._get_metadata_for_step(
#     656             step_idx=len(self) - 1,
#     657             step_params=routed_params[self.steps[-1][0]],
#     658             all_params=params,
#     659         )
# --> 660         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     662 return self
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\svm\_base.py:257, in BaseLibSVM.fit(self, X, y, sample_weight)
#     254     print("[LibSVM]", end="")
#     256 seed = rnd.randint(np.iinfo("i").max)
# --> 257 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     258 # see comment on the other call to np.iinfo in this file
#     260 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\svm\_base.py:376, in BaseLibSVM._sparse_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     362 kernel_type = self._sparse_kernels.index(kernel)
#     364 libsvm_sparse.set_verbosity_wrap(self.verbose)
#     366 (
#     367     self.support_,
#     368     self.support_vectors_,
#     369     dual_coef_data,
#     370     self.intercept_,
#     371     self._n_support,
#     372     self._probA,
#     373     self._probB,
#     374     self.fit_status_,
#     375     self._num_iter,
# --> 376 ) = libsvm_sparse.libsvm_sparse_train(
#     377     X.shape[1],
#     378     X.data,
#     379     X.indices,
#     380     X.indptr,
#     381     y,
#     382     solver_type,
#     383     kernel_type,
#     384     self.degree,
#     385     self._gamma,
#     386     self.coef0,
#     387     self.tol,
#     388     self.C,
#     389     getattr(self, "class_weight_", np.empty(0)),
#     390     sample_weight,
#     391     self.nu,
#     392     self.cache_size,
#     393     self.epsilon,
#     394     int(self.shrinking),
#     395     int(self.probability),
#     396     self.max_iter,
#     397     random_seed,
#     398 )
#     400 self._warn_from_fit_status()
#     402 if hasattr(self, "classes_"):
#
# File _libsvm_sparse.pyx:218, in sklearn.svm._libsvm_sparse.libsvm_sparse_train()
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\sparse\_compressed.py:27, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      22 class _cs_matrix(_data_matrix, _minmax_mixin, IndexMixin):
#      23     """
#      24     base array/matrix class for compressed row- and column-oriented arrays/matrices
#      25     """
# ---> 27     def __init__(self, arg1, shape=None, dtype=None, copy=False):
#      28         _data_matrix.__init__(self, arg1)
#      29         is_array = isinstance(self, sparray)
#
# KeyboardInterrupt:

# %%
pipe.score(testX, testY)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 pipe.score(testX, testY)
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\pipeline.py:1197, in Pipeline.score(self, X, y, sample_weight, **params)
#    1195     if sample_weight is not None:
#    1196         score_params["sample_weight"] = sample_weight
# -> 1197     return self.steps[-1][1].score(Xt, y, **score_params)
#    1199 # metadata routing is enabled.
#    1200 routed_params = process_routing(
#    1201     self, "score", sample_weight=sample_weight, **params
#    1202 )
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:572, in ClassifierMixin.score(self, X, y, sample_weight)
#     547 """
#     548 Return the mean accuracy on the given test data and labels.
#     549
#    (...)
#     568     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     569 """
#     570 from .metrics import accuracy_score
# --> 572 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\svm\_base.py:821, in BaseSVC.predict(self, X)
#     819     y = np.argmax(self.decision_function(X), axis=1)
#     820 else:
# --> 821     y = super().predict(X)
#     822 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\svm\_base.py:435, in BaseLibSVM.predict(self, X)
#     419 def predict(self, X):
#     420     """Perform regression on samples in X.
#     421
#     422     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     433         The predicted values.
#     434     """
# --> 435     X = self._validate_for_predict(X)
#     436     predict = self._sparse_predict if self._sparse else self._dense_predict
#     437     return predict(X)
#
# File c:\Users\Nwamaka E Okonkwo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\svm\_base.py:643, in BaseLibSVM._validate_for_predict(self, X)
#     636         raise ValueError(
#     637             "X.shape[1] = %d should be equal to %d, "
#     638             "the number of samples at training time"
#     639             % (X.shape[1], self.shape_fit_[0])
#     640         )
#     641 # Fixes https://nvd.nist.gov/vuln/detail/CVE-2020-28975
#     642 # Check that _n_support is consistent with support_vectors
# --> 643 sv = self.support_vectors_
#     644 if not self._sparse and sv.size > 0 and self.n_support_.sum() != sv.shape[0]:
#     645     raise ValueError(
#     646         f"The internal representation of {self.__class__.__name__} was altered"
#     647     )
#
# AttributeError: 'SVC' object has no attribute 'support_vectors_'

# %%
preds = pipe.predict(testX)

print(classification_report(testY, preds))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 preds = pipe.predict(testX)
#       3 print(classification_report(testY, preds))
#
# NameError: name 'pipe' is not defined

# %%
plot_confusion_matrix(pipe, testX, testY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plot_confusion_matrix(pipe, testX, testY)
#
# NameError: name 'plot_confusion_matrix' is not defined

# %%
import pickle

# Save model
with open('predictor.pkl', 'wb') as f:
    pickle.dump(grid, f)

# Load model
with open('predictor.pkl', 'rb') as f:
    loaded_model = pickle.load(f)
